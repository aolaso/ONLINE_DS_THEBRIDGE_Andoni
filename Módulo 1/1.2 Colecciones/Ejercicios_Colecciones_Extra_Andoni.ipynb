# %% [markdown]
# ## Ejercicio Extra
# Programa el SW de una biblioteca:
#
# * Preguntar qué operación quieres realizar (visualizar todos los libros de la biblioteca/buscar libro/añadir libro/eliminar libro por título)
#     * En caso de que pida el usuario elija visualizar se visualizarán todos los libros
#     * Buscar libro: búsqueda por título que introduce el usuario y se visualiza todos los campos del libro
#     * Añadir libro: se debe solicitar al usuario que introduzca título y autor para el nuevo libro y se añade el libro a la lista de libros
#     * Eliminar libro: se solicita al usuario el título del libro y éste debe ser eliminado de la lista de libros
#     * Alquilar libro: se solicita al usuario el título del libro y se debe pasar el campo "Alquilado" a True
#     * Devolver libro: se solicita al usuario el título del libro y se debe pasar el campo "Alquilado" a False

# %%
libros = [
    {"Titulo": "Python Data Science Handbook", "Autor": "Jake VanderPlas", "Alquilado": False},
    {"Titulo": "Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow", "Autor": "Aurélien Géron", "Alquilado": True},
    {"Titulo": "Pattern Recognition and Machine Learning", "Autor": "Christopher M. Bishop", "Alquilado": False},
    {"Titulo": "Deep Learning", "Autor": "Ian Goodfellow, Yoshua Bengio, Aaron Courville", "Alquilado": True},
    {"Titulo": "The Elements of Statistical Learning", "Autor": "Trevor Hastie, Robert Tibshirani, Jerome Friedman", "Alquilado": False},
    {"Titulo": "Data Science for Business", "Autor": "Foster Provost, Tom Fawcett", "Alquilado": False},
    {"Titulo": "Bayesian Data Analysis", "Autor": "Andrew Gelman et al.", "Alquilado": True},
    {"Titulo": "Introduction to the Theory of Computation", "Autor": "Michael Sipser", "Alquilado": False},
    {"Titulo": "Artificial Intelligence: A Modern Approach", "Autor": "Stuart Russell, Peter Norvig", "Alquilado": True},
    {"Titulo": "Computer Vision: Algorithms and Applications", "Autor": "Richard Szeliski", "Alquilado": False},
    {"Titulo": "Data Science from Scratch", "Autor": "Joel Grus", "Alquilado": True},
    {"Titulo": "The Art of Statistics", "Autor": "David Spiegelhalter", "Alquilado": False},
    {"Titulo": "Python Machine Learning", "Autor": "Sebastian Raschka, Vahid Mirjalili", "Alquilado": True},
    {"Titulo": "An Introduction to Statistical Learning", "Autor": "Gareth James, Daniela Witten, Trevor Hastie, Robert Tibshirani", "Alquilado": False},
    {"Titulo": "Fundamentals of Data Engineering", "Autor": "Joe Reis, Matt Housley", "Alquilado": False},
    {"Titulo": "Storytelling with Data", "Autor": "Cole Nussbaumer Knaflic", "Alquilado": True},
    {"Titulo": "Building Machine Learning Powered Applications", "Autor": "Emmanuel Ameisen", "Alquilado": False},
    {"Titulo": "Practical Statistics for Data Scientists", "Autor": "Peter Bruce, Andrew Bruce", "Alquilado": True},
    {"Titulo": "SQL for Data Scientists", "Autor": "Renee M. P. Teate", "Alquilado": False},
    {"Titulo": "Data Engineering on Azure", "Autor": "Vlad Riscutia", "Alquilado": True}
]

# %%
# LO HE HECHO CON MUCHA AYUDA DE GEMINI (IA) PARA QUE ME EXPLIQUE PASO POR PASO LO QUE SIGNIFICA CADA BUCLE Y EL EJERCICIO ENTERO. 

libros = [
    {"Titulo": "Python Data Science Handbook", "Autor": "Jake VanderPlas", "Alquilado": False},
    {"Titulo": "Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow", "Autor": "Aurélien Géron", "Alquilado": True},
    {"Titulo": "Pattern Recognition and Machine Learning", "Autor": "Christopher M. Bishop", "Alquilado": False},
    {"Titulo": "Deep Learning", "Autor": "Ian Goodfellow, Yoshua Bengio, Aaron Courville", "Alquilado": True},
    {"Titulo": "The Elements of Statistical Learning", "Autor": "Trevor Hastie, Robert Tibshirani, Jerome Friedman", "Alquilado": False},
    {"Titulo": "Data Science for Business", "Autor": "Foster Provost, Tom Fawcett", "Alquilado": False},
    {"Titulo": "Bayesian Data Analysis", "Autor": "Andrew Gelman et al.", "Alquilado": True},
    {"Titulo": "Introduction to the Theory of Computation", "Autor": "Michael Sipser", "Alquilado": False},
    {"Titulo": "Artificial Intelligence: A Modern Approach", "Autor": "Stuart Russell, Peter Norvig", "Alquilado": True},
    {"Titulo": "Computer Vision: Algorithms and Applications", "Autor": "Richard Szeliski", "Alquilado": False},
    {"Titulo": "Data Science from Scratch", "Autor": "Joel Grus", "Alquilado": True},
    {"Titulo": "The Art of Statistics", "Autor": "David Spiegelhalter", "Alquilado": False},
    {"Titulo": "Python Machine Learning", "Autor": "Sebastian Raschka, Vahid Mirjalili", "Alquilado": True},
    {"Titulo": "An Introduction to Statistical Learning", "Autor": "Gareth James, Daniela Witten, Trevor Hastie, Robert Tibshirani", "Alquilado": False},
    {"Titulo": "Fundamentals of Data Engineering", "Autor": "Joe Reis, Matt Housley", "Alquilado": False},
    {"Titulo": "Storytelling with Data", "Autor": "Cole Nussbaumer Knaflic", "Alquilado": True},
    {"Titulo": "Building Machine Learning Powered Applications", "Autor": "Emmanuel Ameisen", "Alquilado": False},
    {"Titulo": "Practical Statistics for Data Scientists", "Autor": "Peter Bruce, Andrew Bruce", "Alquilado": True},
    {"Titulo": "SQL for Data Scientists", "Autor": "Renee M. P. Teate", "Alquilado": False},
    {"Titulo": "Data Engineering on Azure", "Autor": "Vlad Riscutia", "Alquilado": True}
]

while True:
    print("\n" + "="*40)
    print("SOFTWARE DE BIBLIOTECA")
    print("="*40)
    print("1. Visualizar todos los libros")
    print("2. Buscar libro")
    print("3. Añadir libro")
    print("4. Eliminar libro")
    print("5. Alquilar libro")
    print("6. Devolver libro")
    print("7. Salir")
    
    opcion = input("\n¿Qué operación quieres realizar? (1-7): ")

    if opcion == "1":
        print("\n--- LISTA TOTAL DE LIBROS ---")
        for libro in libros:
            # Traducción rápida para el listado
            estado = "Alquilado" if libro["Alquilado"] else "Disponible"
            print(f"- {libro['Titulo']} ({libro['Autor']}) -> [{estado}]")

    elif opcion == "2":
        busqueda = input("Introduce el título exacto: ")
        encontrado = False
        for libro in libros:
            if libro["Titulo"].lower() == busqueda.lower():
                # Traducción humana del True/False
                estado = "Alquilado" if libro["Alquilado"] else "No alquilado"
                print(f"\nINFO: {libro['Titulo']} | Autor: {libro['Autor']} | Estado: {estado}")
                encontrado = True
                break # Aquí SÍ ponemos break para dejar de buscar en el FOR
        if not encontrado:
            print("No se ha encontrado el libro.")

    elif opcion == "3":
        t = input("Título: ")
        a = input("Autor: ")
        libros.append({"Titulo": t, "Autor": a, "Alquilado": False})
        print("¡Libro guardado!")

    elif opcion == "4":
        t_borrar = input("Título para eliminar: ")
        for libro in libros:
            if libro["Titulo"].lower() == t_borrar.lower():
                libros.remove(libro)
                print("Libro borrado correctamente.")
                break

    elif opcion == "5":
        t_alquilar = input("Título para alquilar: ")
        for libro in libros:
            if libro["Titulo"].lower() == t_alquilar.lower():
                libro["Alquilado"] = True
                print("Estado actualizado: ALQUILADO.")
                break

    elif opcion == "6":
        t_devolver = input("Título para devolver: ")
        for libro in libros:
            if libro["Titulo"].lower() == t_devolver.lower():
                libro["Alquilado"] = False
                print("Estado actualizado: DISPONIBLE.")
                break

    elif opcion == "7":
        print("Cerrando el sistema... ¡Hasta luego!")
        break # Aquí SÍ ponemos break para salir del WHILE (cerrar programa)

    else:
        print("Opción incorrecta.")
# Out:
# ========================================
# SOFTWARE DE BIBLIOTECA
# ========================================
# 1. Visualizar todos los libros
# 2. Buscar libro
# 3. Añadir libro
# 4. Eliminar libro
# 5. Alquilar libro
# 6. Devolver libro
# 7. Salir
#
# --- LISTA TOTAL DE LIBROS ---
# - Python Data Science Handbook (Jake VanderPlas) -> [Disponible]
# - Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow (Aurélien Géron) -> [Alquilado]
# - Pattern Recognition and Machine Learning (Christopher M. Bishop) -> [Disponible]
# - Deep Learning (Ian Goodfellow, Yoshua Bengio, Aaron Courville) -> [Alquilado]
# - The Elements of Statistical Learning (Trevor Hastie, Robert Tibshirani, Jerome Friedman) -> [Disponible]
# - Data Science for Business (Foster Provost, Tom Fawcett) -> [Disponible]
# - Bayesian Data Analysis (Andrew Gelman et al.) -> [Alquilado]
# - Introduction to the Theory of Computation (Michael Sipser) -> [Disponible]
# - Artificial Intelligence: A Modern Approach (Stuart Russell, Peter Norvig) -> [Alquilado]
# - Computer Vision: Algorithms and Applications (Richard Szeliski) -> [Disponible]
# - Data Science from Scratch (Joel Grus) -> [Alquilado]
# - The Art of Statistics (David Spiegelhalter) -> [Disponible]
# - Python Machine Learning (Sebastian Raschka, Vahid Mirjalili) -> [Alquilado]
# - An Introduction to Statistical Learning (Gareth James, Daniela Witten, Trevor Hastie, Robert Tibshirani) -> [Disponible]
# - Fundamentals of Data Engineering (Joe Reis, Matt Housley) -> [Disponible]
# - Storytelling with Data (Cole Nussbaumer Knaflic) -> [Alquilado]
# - Building Machine Learning Powered Applications (Emmanuel Ameisen) -> [Disponible]
# - Practical Statistics for Data Scientists (Peter Bruce, Andrew Bruce) -> [Alquilado]
# - SQL for Data Scientists (Renee M. P. Teate) -> [Disponible]
# - Data Engineering on Azure (Vlad Riscutia) -> [Alquilado]
#
# ========================================
# SOFTWARE DE BIBLIOTECA
# ========================================
# 1. Visualizar todos los libros
# 2. Buscar libro
# 3. Añadir libro
# 4. Eliminar libro
# 5. Alquilar libro
# 6. Devolver libro
# 7. Salir
# No se ha encontrado el libro.
#
# ========================================
# SOFTWARE DE BIBLIOTECA
# ========================================
# 1. Visualizar todos los libros
# 2. Buscar libro
# 3. Añadir libro
# 4. Eliminar libro
# 5. Alquilar libro
# 6. Devolver libro
# 7. Salir
# ¡Libro guardado!
#
# ========================================
# SOFTWARE DE BIBLIOTECA
# ========================================
# 1. Visualizar todos los libros
# 2. Buscar libro
# 3. Añadir libro
# 4. Eliminar libro
# 5. Alquilar libro
# 6. Devolver libro
# 7. Salir
#
# ========================================
# SOFTWARE DE BIBLIOTECA
# ========================================
# 1. Visualizar todos los libros
# 2. Buscar libro
# 3. Añadir libro
# 4. Eliminar libro
# 5. Alquilar libro
# 6. Devolver libro
# 7. Salir
# Libro borrado correctamente.
#
# ========================================
# SOFTWARE DE BIBLIOTECA
# ========================================
# 1. Visualizar todos los libros
# 2. Buscar libro
# 3. Añadir libro
# 4. Eliminar libro
# 5. Alquilar libro
# 6. Devolver libro
# 7. Salir
# Estado actualizado: ALQUILADO.
#
# ========================================
# SOFTWARE DE BIBLIOTECA
# ========================================
# 1. Visualizar todos los libros
# 2. Buscar libro
# 3. Añadir libro
# 4. Eliminar libro
# 5. Alquilar libro
# 6. Devolver libro
# 7. Salir
# Estado actualizado: DISPONIBLE.
#
# ========================================
# SOFTWARE DE BIBLIOTECA
# ========================================
# 1. Visualizar todos los libros
# 2. Buscar libro
# 3. Añadir libro
# 4. Eliminar libro
# 5. Alquilar libro
# 6. Devolver libro
# 7. Salir
# Cerrando el sistema... ¡Hasta luego!
